# %% [markdown]
# <a href="https://colab.research.google.com/github/mashyko/object_detection/blob/master/YOLOv3_ultralyics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # YOLOv3 Pytorch implementation
#
# This notebook contains software developed by Ultralytics LLC, and is freely available for redistribution under the GPL-3.0 license. For more information please visit https://github.com/ultralytics/yolov3 and https://www.ultralytics.com.
#
# YOLOv4 は以下のGitHub にあります
#
# https://github.com/AlexeyAB/darknet

# %%
! git clone https://github.com/ultralytics/yolov3
#!pip install -U -r yolov3/requirements.txt  # install dependencies
# %cd yolov3
# Out:
# fatal: destination path 'yolov3' already exists and is not an empty directory.
# /content/yolov3

# %% [markdown]
# pretrained modelとしてyolov3.weights を使用

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-06-19 05:20:00--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights.1’
#
# yolov3.weights.1    100%[===================>] 236.52M   467KB/s    in 9m 45s
#
# 2020-06-19 05:29:47 (414 KB/s) - ‘yolov3.weights.1’ saved [248007048/248007048]

# %% [markdown]
# Run `detect.py` to perform inference on images in `data/samples` folder:

# %%
# !python3 detect.py --cfg cfg/yolov3.cfg --weights yolov3.pt

# %%
# !ls output/
# Out:
# bus.jpg  zidane.jpg

# %%
from IPython.display import Image, clear_output
Image(filename='output/bus.jpg', width=600)

# %%
Image(filename='output/zidane.jpg', width=600)

# %% [markdown]
# #Training
# Start Training: python3 train.py to begin training after downloading COCO data with data/get_coco2017.sh.
#
# Each epoch trains on 117,263 images from the train and validate COCO sets, and tests on 5000 images from the COCO validate set.

# %% [markdown]
# Download COCO 2014 dataset (20GB): ２０GBをダウンロードするので、相当な時間がかかります

# %%
# !bash ./data/get_coco_dataset_gdrive.sh  # copy COCO2014 dataset (19GB)

# %%
# !python3 train.py
